# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv('drugs.csv')
df
# Out:
#    Monitoring the Future Study: Trends in Prevalence of Various Drugs for 8th Graders, 10th Graders, and 12th Graders; 2015 - 2018 (in percent)*  \
# 0                                                Drug
# 1                                                 NaN
# 2                                             Alcohol
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                Cigarettes (any use)
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                       E-cigarettes
# 11                                         Any Vaping
# 12                                                NaN
# 13                                                NaN
# 14                                  Smokeless Tobacco
# ...

# %%
df = df[:11]
